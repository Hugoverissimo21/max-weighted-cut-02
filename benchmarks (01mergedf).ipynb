# %%
import os
import pandas as pd

# %%
datas = [x for x in os.listdir() if "results_" in x and ".xlsx" in x]
datas
datas = ["results v02.xlsx", "all_results.xlsx"]
datas = ["results v03.xlsx", "results_1125205844.xlsx"]

# %%
dfs = []
for data in datas:
    dfs.append(pd.read_excel(data, index_col=0, header=[0,1]))

all_data = pd.concat(dfs, ignore_index=True)

# %%
all_data[all_data[("Graph", "name")] == "graphs/0004_250.graphml"]
# Out:
#                         Graph              Exhaustive                  \
#                          name  n  m weight       #ops      time #sols
# 877   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 878   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 879   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 880   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 881   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 882   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 883   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 884   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 885   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 886   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 887   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 888   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 889   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 890   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 891   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 892   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 893   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 894   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 895   graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 5518  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
#
#      Heuristic                  ... Random Solutions (MS: 100)            \
#           #ops      time #sols  ...                       #ops      time
# 877         28  0.000008     1  ...                        NaN       NaN
# 878         28  0.000008     1  ...                      242.0  0.000126
# 879         28  0.000008     1  ...                        NaN       NaN
# 880         28  0.000008     1  ...                        NaN       NaN
# 881         28  0.000008     1  ...                      238.0  0.000128
# 882         28  0.000008     1  ...                        NaN       NaN
# 883         28  0.000008     1  ...                        NaN       NaN
# 884         28  0.000008     1  ...                        NaN       NaN
# 885         28  0.000008     1  ...                        NaN       NaN
# 886         28  0.000008     1  ...                        NaN       NaN
# 887         28  0.000008     1  ...                        NaN       NaN
# 888         28  0.000008     1  ...                        NaN       NaN
# 889         28  0.000008     1  ...                        NaN       NaN
# 890         28  0.000008     1  ...                        NaN       NaN
# 891         28  0.000008     1  ...                        NaN       NaN
# 892         28  0.000008     1  ...                        NaN       NaN
# 893         28  0.000008     1  ...                        NaN       NaN
# 894         28  0.000008     1  ...                      242.0  0.000128
# 895         28  0.000008     1  ...                        NaN       NaN
# 5518        28  0.000008     1  ...                        NaN       NaN
#
#                                  Simulated Annealing (T: 1000, CR: 0.9)  \
#      #sols prec.   it. prec./it.                                   #ops
# 877    NaN   NaN   NaN       NaN                                    NaN
# 878   16.0   1.0  52.0  0.153846                                  685.0
# 879    NaN   NaN   NaN       NaN                                    NaN
# 880    NaN   NaN   NaN       NaN                                    NaN
# 881   16.0   1.0  51.0  0.156863                                  691.0
# 882    NaN   NaN   NaN       NaN                                    NaN
# 883    NaN   NaN   NaN       NaN                                    NaN
# 884    NaN   NaN   NaN       NaN                                    NaN
# 885    NaN   NaN   NaN       NaN                                    NaN
# 886    NaN   NaN   NaN       NaN                                    NaN
# 887    NaN   NaN   NaN       NaN                                    NaN
# 888    NaN   NaN   NaN       NaN                                    NaN
# 889    NaN   NaN   NaN       NaN                                    NaN
# 890    NaN   NaN   NaN       NaN                                    NaN
# 891    NaN   NaN   NaN       NaN                                    NaN
# 892    NaN   NaN   NaN       NaN                                    NaN
# 893    NaN   NaN   NaN       NaN                                    NaN
# 894   16.0   1.0  52.0  0.153846                                  676.0
# 895    NaN   NaN   NaN       NaN                                    NaN
# 5518   NaN   NaN   NaN       NaN                                    NaN
#
#
#           time  #sols prec.
# 877        NaN    NaN   NaN
# 878   0.000214  133.0   1.0
# 879        NaN    NaN   NaN
# 880        NaN    NaN   NaN
# 881   0.000224  133.0   1.0
# 882        NaN    NaN   NaN
# 883        NaN    NaN   NaN
# 884        NaN    NaN   NaN
# 885        NaN    NaN   NaN
# 886        NaN    NaN   NaN
# 887        NaN    NaN   NaN
# 888        NaN    NaN   NaN
# 889        NaN    NaN   NaN
# 890        NaN    NaN   NaN
# 891        NaN    NaN   NaN
# 892        NaN    NaN   NaN
# 893        NaN    NaN   NaN
# 894   0.000208  133.0   1.0
# 895        NaN    NaN   NaN
# 5518       NaN    NaN   NaN
#
# [20 rows x 53 columns]

# %%
all_data
# Out:
#                       Graph                        Exhaustive             \
#                        name      n      m   weight       #ops time #sols
# 0      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 1      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 2      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 3      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 4      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# ...                     ...    ...    ...      ...        ...  ...   ...
# 5841   graphs (gset)/G7.txt    800  19176   2006.0        NaN  NaN   NaN
# 5842  graphs (gset)/G70.txt  10000   9999   9591.0        NaN  NaN   NaN
# 5843  graphs (gset)/G72.txt  10000  20000   7006.0        NaN  NaN   NaN
# 5844   graphs (gset)/G8.txt    800  19176   2005.0        NaN  NaN   NaN
# 5845   graphs (gset)/G9.txt    800  19176   2054.0        NaN  NaN   NaN
#
#        Heuristic                   ... Random Solutions (MS: 100)            \
#             #ops       time #sols  ...                       #ops      time
# 0        6225342   0.141065     1  ...                        NaN       NaN
# 1        6225342   0.141065     1  ...                        NaN       NaN
# 2        6225342   0.141065     1  ...                        NaN       NaN
# 3        6225342   0.141065     1  ...                        NaN       NaN
# 4        6225342   0.141065     1  ...                  1997712.0  0.155277
# ...          ...        ...   ...  ...                        ...       ...
# 5841     6224765   0.143155     1  ...                        NaN       NaN
# 5842  1324406540  25.946424     1  ...                        NaN       NaN
# 5843  1324879857  26.921012     1  ...                        NaN       NaN
# 5844     6223580   0.144396     1  ...                        NaN       NaN
# 5845     6228653   0.140115     1  ...                        NaN       NaN
#
#                                        Simulated Annealing (T: 1000, CR: 0.9)  \
#       #sols     prec.    it. prec./it.                                   #ops
# 0       NaN       NaN    NaN       NaN                                    NaN
# 1       NaN       NaN    NaN       NaN                                    NaN
# 2       NaN       NaN    NaN       NaN                                    NaN
# 3       NaN       NaN    NaN       NaN                                    NaN
# 4     100.0  0.838094  100.0  0.824238                              2551899.0
# ...     ...       ...    ...       ...                                    ...
# 5841    NaN       NaN    NaN       NaN                                    NaN
# 5842    NaN       NaN    NaN       NaN                                    NaN
# 5843    NaN       NaN    NaN       NaN                                    NaN
# 5844    NaN       NaN    NaN       NaN                                    NaN
# 5845    NaN       NaN    NaN       NaN                                    NaN
#
#
#           time  #sols     prec.
# 0          NaN    NaN       NaN
# 1          NaN    NaN       NaN
# 2          NaN    NaN       NaN
# 3          NaN    NaN       NaN
# 4     0.163341  133.0  0.842395
# ...        ...    ...       ...
# 5841       NaN    NaN       NaN
# 5842       NaN    NaN       NaN
# 5843       NaN    NaN       NaN
# 5844       NaN    NaN       NaN
# 5845       NaN    NaN       NaN
#
# [5846 rows x 53 columns]

# %%
df = all_data.sort_values(by=("Graph", "name"), ascending=True)
df = df.reset_index(drop=True)
df.to_excel("all_results1.xlsx")

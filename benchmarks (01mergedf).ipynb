# %%
import os
import pandas as pd

# %%
datas = [x for x in os.listdir() if "results_" in x and ".xlsx" in x]
datas
datas = ["results v02.xlsx", "all_results.xlsx"]
datas = ["results v03.xlsx", "results_1125205844.xlsx"]
datas = ["results v04.xlsx", "results_1128130656.xlsx"]
datas = ["results v05.xlsx", "results_1129231849.xlsx", "results_1129232646.xlsx",
         "results_1129232703.xlsx", "results_1129233156.xlsx"]

# %%
dfs = []
for data in datas:
    dfs.append(pd.read_excel(data, index_col=0, header=[0,1]))

all_data = pd.concat(dfs, ignore_index=True)

# %%
all_data[all_data[("Graph", "name")] == "graphs/0004_250.graphml"]
# Out:
#                         Graph              Exhaustive                  \
#                          name  n  m weight       #ops      time #sols
# 1017  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1018  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1019  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1020  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1021  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1022  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1023  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1024  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1025  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1026  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1027  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1028  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1029  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1030  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1031  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1032  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1033  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1034  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1035  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1036  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 1037  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 6176  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 6505  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 6834  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
# 7163  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0
#
#      Heuristic                  ... Random Solutions (MS: 100)            \
#           #ops      time #sols  ...                        it. prec./it.
# 1017        28  0.000008     1  ...                       52.0  0.153846
# 1018        28  0.000008     1  ...                        NaN       NaN
# 1019        28  0.000008     1  ...                        NaN       NaN
# 1020        28  0.000008     1  ...                        NaN       NaN
# 1021        28  0.000008     1  ...                        NaN       NaN
# 1022        28  0.000008     1  ...                        NaN       NaN
# 1023        28  0.000008     1  ...                        NaN       NaN
# 1024        28  0.000008     1  ...                        NaN       NaN
# 1025        28  0.000008     1  ...                        NaN       NaN
# 1026        28  0.000008     1  ...                        NaN       NaN
# 1027        28  0.000008     1  ...                        NaN       NaN
# 1028        28  0.000008     1  ...                        NaN       NaN
# 1029        28  0.000008     1  ...                        NaN       NaN
# 1030        28  0.000008     1  ...                        NaN       NaN
# 1031        28  0.000008     1  ...                        NaN       NaN
# 1032        28  0.000008     1  ...                       52.0  0.153846
# 1033        28  0.000008     1  ...                        NaN       NaN
# 1034        28  0.000008     1  ...                        NaN       NaN
# 1035        28  0.000008     1  ...                        NaN       NaN
# 1036        28  0.000008     1  ...                       51.0  0.156863
# 1037        28  0.000008     1  ...                        NaN       NaN
# 6176        28  0.000008     1  ...                        NaN       NaN
# 6505        28  0.000008     1  ...                        NaN       NaN
# 6834        28  0.000008     1  ...                        NaN       NaN
# 7163        28  0.000008     1  ...                        NaN       NaN
#
#      Simulated Annealing (T: 1000, CR: 0.9)                         \
#                                        #ops      time  #sols prec.
# 1017                                  685.0  0.000214  133.0   1.0
# 1018                                    NaN       NaN    NaN   NaN
# 1019                                    NaN       NaN    NaN   NaN
# 1020                                    NaN       NaN    NaN   NaN
# 1021                                    NaN       NaN    NaN   NaN
# 1022                                    NaN       NaN    NaN   NaN
# 1023                                    NaN       NaN    NaN   NaN
# 1024                                    NaN       NaN    NaN   NaN
# 1025                                    NaN       NaN    NaN   NaN
# 1026                                    NaN       NaN    NaN   NaN
# 1027                                    NaN       NaN    NaN   NaN
# 1028                                    NaN       NaN    NaN   NaN
# 1029                                    NaN       NaN    NaN   NaN
# 1030                                    NaN       NaN    NaN   NaN
# 1031                                    NaN       NaN    NaN   NaN
# 1032                                  676.0  0.000208  133.0   1.0
# 1033                                    NaN       NaN    NaN   NaN
# 1034                                    NaN       NaN    NaN   NaN
# 1035                                    NaN       NaN    NaN   NaN
# 1036                                  691.0  0.000224  133.0   1.0
# 1037                                    NaN       NaN    NaN   NaN
# 6176                                    NaN       NaN    NaN   NaN
# 6505                                    NaN       NaN    NaN   NaN
# 6834                                    NaN       NaN    NaN   NaN
# 7163                                    NaN       NaN    NaN   NaN
#
#      Random Greedy (IT: 0.01)
#                          #ops      time #sols prec.
# 1017                      NaN       NaN   NaN   NaN
# 1018                      NaN       NaN   NaN   NaN
# 1019                     19.0  0.000014   5.0   1.0
# 1020                      NaN       NaN   NaN   NaN
# 1021                      NaN       NaN   NaN   NaN
# 1022                      NaN       NaN   NaN   NaN
# 1023                      NaN       NaN   NaN   NaN
# 1024                      NaN       NaN   NaN   NaN
# 1025                      NaN       NaN   NaN   NaN
# 1026                      NaN       NaN   NaN   NaN
# 1027                      NaN       NaN   NaN   NaN
# 1028                      NaN       NaN   NaN   NaN
# 1029                      NaN       NaN   NaN   NaN
# 1030                      NaN       NaN   NaN   NaN
# 1031                      NaN       NaN   NaN   NaN
# 1032                      NaN       NaN   NaN   NaN
# 1033                      NaN       NaN   NaN   NaN
# 1034                      NaN       NaN   NaN   NaN
# 1035                      NaN       NaN   NaN   NaN
# 1036                      NaN       NaN   NaN   NaN
# 1037                      NaN       NaN   NaN   NaN
# 6176                     19.0  0.000019   5.0   1.0
# 6505                      NaN       NaN   NaN   NaN
# 6834                      NaN       NaN   NaN   NaN
# 7163                      NaN       NaN   NaN   NaN
#
# [25 rows x 57 columns]

# %%
all_data
# Out:
#                       Graph                        Exhaustive             \
#                        name      n      m   weight       #ops time #sols
# 0      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 1      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 2      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 3      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# 4      graphs (gset)/G1.txt    800  19176  11624.0        NaN  NaN   NaN
# ...                     ...    ...    ...      ...        ...  ...   ...
# 7486   graphs (gset)/G7.txt    800  19176   2006.0        NaN  NaN   NaN
# 7487  graphs (gset)/G70.txt  10000   9999   9591.0        NaN  NaN   NaN
# 7488  graphs (gset)/G72.txt  10000  20000   7006.0        NaN  NaN   NaN
# 7489   graphs (gset)/G8.txt    800  19176   2005.0        NaN  NaN   NaN
# 7490   graphs (gset)/G9.txt    800  19176   2054.0        NaN  NaN   NaN
#
#        Heuristic                   ... Random Solutions (MS: 100)            \
#             #ops       time #sols  ...                        it. prec./it.
# 0        6225342   0.141065     1  ...                        NaN       NaN
# 1        6225342   0.141065     1  ...                        NaN       NaN
# 2        6225342   0.141065     1  ...                        NaN       NaN
# 3        6225342   0.141065     1  ...                        NaN       NaN
# 4        6225342   0.141065     1  ...                        NaN       NaN
# ...          ...        ...   ...  ...                        ...       ...
# 7486     6224765   0.143155     1  ...                        NaN       NaN
# 7487  1324406540  25.946424     1  ...                        NaN       NaN
# 7488  1324879857  26.921012     1  ...                        NaN       NaN
# 7489     6223580   0.144396     1  ...                        NaN       NaN
# 7490     6228653   0.140115     1  ...                        NaN       NaN
#
#      Simulated Annealing (T: 1000, CR: 0.9)                   \
#                                        #ops time #sols prec.
# 0                                       NaN  NaN   NaN   NaN
# 1                                       NaN  NaN   NaN   NaN
# 2                                       NaN  NaN   NaN   NaN
# 3                                       NaN  NaN   NaN   NaN
# 4                                       NaN  NaN   NaN   NaN
# ...                                     ...  ...   ...   ...
# 7486                                    NaN  NaN   NaN   NaN
# 7487                                    NaN  NaN   NaN   NaN
# 7488                                    NaN  NaN   NaN   NaN
# 7489                                    NaN  NaN   NaN   NaN
# 7490                                    NaN  NaN   NaN   NaN
#
#      Random Greedy (IT: 0.01)
#                          #ops time #sols prec.
# 0                         NaN  NaN   NaN   NaN
# 1                         NaN  NaN   NaN   NaN
# 2                         NaN  NaN   NaN   NaN
# 3                         NaN  NaN   NaN   NaN
# 4                         NaN  NaN   NaN   NaN
# ...                       ...  ...   ...   ...
# 7486                      NaN  NaN   NaN   NaN
# 7487                      NaN  NaN   NaN   NaN
# 7488                      NaN  NaN   NaN   NaN
# 7489                      NaN  NaN   NaN   NaN
# 7490                      NaN  NaN   NaN   NaN
#
# [7491 rows x 57 columns]

# %%
df = all_data.sort_values(by=("Graph", "name"), ascending=True)
df = df.reset_index(drop=True)
df.to_excel("results v07.xlsx")

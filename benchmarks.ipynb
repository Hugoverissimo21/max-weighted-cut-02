# %%
import networkx as nx
import random
import math

# %% [markdown]
# # funcoes para ler grafos

# %%
def adjacency_matrix_to_edges(G_graphml):
    matrix = nx.adjacency_matrix(nx.read_graphml(G_graphml)).todense()
    edges = []
    n = len(matrix)  # assuming matrix is square
    for u in range(n):
        for v in range(u, n):
            if matrix[u][v] != 0:  # assuming 0 means no edge
                edges.append((u, v, matrix[u][v]))
    return edges, n, len(edges)

G = 'graphs/0004_125.graphml'
edges, n_nodes, m = adjacency_matrix_to_edges(G)

# %%
def edges_from_Bgraph(filename):
    edges = []
    with open(filename, 'r') as file:
        # Skip the first line
        if "gset" in filename:
            n_nodes, n_edges = file.readline().split()
            n_nodes, n_edges = int(n_nodes), int(n_edges)
        else:
            file.readline()
            file.readline()
            n_nodes = int(file.readline().split()[0])
            n_edges = int(file.readline().split()[0])
        for line in file:
            # Split each line into components and convert to appropriate types
            node1, node2, weight = line.split()
            edges.append((int(node1)-1, int(node2)-1, float(weight)))
    return edges, n_nodes, n_edges

#path = """graphs (gset)/G59.txt"""
#edges_from_Bgraph(path)

# %% [markdown]
# # algorimos

# %%
def random_solution(edges, n_nodes, solutions=10000):
    SOLTESTED, OPSEXEC = 0, 0

    best_solution = {node: 0 for node in range(n_nodes)}
    best_cut_weight = 0
    seen_solutions = set()

    MEAN_WEIGHT = 0
    for _ in range(solutions):
        # Generate a random candidate solution
        partition = {node: random.choice([0, 1]) for node in range(n_nodes)}
        OPSEXEC += n_nodes
        # avoid calculating the same solution multiple times
        partition_hash = frozenset(partition.items()) # hash
        # nao vou contabilizar o custo de calcular o hash pq não seria necessário se só testasse uma solucao
        # e em grafos de maior dimensao, a probabilidade de ter solucoes iguais tende para 0 (2^n possiblidades)

        if len(seen_solutions) == 2**(n_nodes): # max possible solutions
            break
        
        if partition_hash in seen_solutions:
            continue

        
        

        seen_solutions.add(partition_hash)
        OPSEXEC += 1
        SOLTESTED += 1
        new_cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
        MEAN_WEIGHT += new_cut_weight
        OPSEXEC += len(edges)
        if new_cut_weight > best_cut_weight:
            best_cut_weight = new_cut_weight
            best_solution = partition.copy()
            OPSEXEC += 2

    actual_it = _ + 1
    S = set([node for node, part in best_solution.items() if part == 0]) #pos processamento, depende do q ser quer, n conta
    T = set(range(n_nodes)) - S #pos processamento, depende do q ser quer, n conta
    return S, T, best_cut_weight, SOLTESTED, OPSEXEC, actual_it, MEAN_WEIGHT/actual_it

S, T, best_cut_weight, SOLTESTED, OPSEXEC, actual_it, MEAN_WEIGHT = random_solution(edges, n_nodes)
S, T, best_cut_weight, SOLTESTED, OPSEXEC, actual_it, MEAN_WEIGHT
# Out:
# ({0, 1, 2, 3}, set(), 0, 16, 272, 64, 0.0)

# %%
def sim_anlng(edges, n_nodes, initial_temp=1000, cooling_rate=0.995, min_temp=1e-3):
    SOLTESTED, OPSEXEC = 0, 0

    nodes = range(n_nodes)
    
    partition = {node: random.choice([0, 1]) for node in nodes}
    OPSEXEC += n_nodes
    
    # Initialize current cost
    current_cut = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
    OPSEXEC += len(edges)
    SOLTESTED += 1

    temperature = initial_temp

    best_partition = partition.copy()
    best_cut = current_cut
    while temperature > min_temp:

        node = random.choice(nodes)
        partition[node] = 1 - partition[node] 
        OPSEXEC += 2
        
        new_cut = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
        OPSEXEC += len(edges)
        SOLTESTED += 1
        
        cost_diff = new_cut - current_cut
        if cost_diff > 0 or random.random() < math.exp(cost_diff / temperature):
            current_cut = new_cut
            if new_cut > best_cut:
                best_cut = new_cut
                best_partition = partition.copy()
                OPSEXEC += 5
        else:
            partition[node] = 1 - partition[node]
            OPSEXEC += 3
        
        temperature *= cooling_rate
        OPSEXEC += 1
    
    S = set([node for node, part in best_partition.items() if part == 0])
    T = set(range(n_nodes)) - S
    return S, T, best_cut, SOLTESTED, OPSEXEC

S, T, best_cut, SOLTESTED, OPSEXEC = sim_anlng(edges, n_nodes)
S, T, best_cut, SOLTESTED, OPSEXEC
# Out:
# ({1, 2, 3}, {0}, 0, 2758, 8275)

# %%
def random_greedy(edges, n_nodes, itLim = 2):
    SOLTESTED, OPSEXEC = 0, 0

    partition = {node: random.choice([0, 1]) for node in range(n_nodes)}
    cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
    SOLTESTED += 1
    OPSEXEC += len(edges) + n_nodes

    improved = True
    it_limit = len(edges) * itLim
    OPSEXEC += 1
    while improved and it_limit > 0:
        it_limit -= 1
        OPSEXEC += 1
        improved = False
        for node in range(n_nodes):
            # Flip the node to the other set
            partition[node] = 1 - partition[node]  
            new_cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
            SOLTESTED += 1
            OPSEXEC += len(edges) + 1

            # If this move improves the cut weight, keep it; otherwise, revert
            if new_cut_weight > cut_weight:
                cut_weight = new_cut_weight
                improved = True  # Continue improving
                OPSEXEC += 2
                break
            else:
                partition[node] = 1 - partition[node]
                OPSEXEC += 1

    S = set([node for node, part in partition.items() if part == 0])
    T = set(range(n_nodes)) - S
    return S, T, cut_weight, SOLTESTED, OPSEXEC

S, T, cut_weight, SOLTESTED, OPSEXEC = random_greedy(edges, n_nodes)
S, T, cut_weight, SOLTESTED, OPSEXEC
# Out:
# ({0, 2, 3}, {1}, 0, 1, 5)

# %% [markdown]
# # benchmarks

# %%
import pandas as pd
from datetime import datetime
import time

df = pd.read_excel('results v00.xlsx', index_col=0, header=[0,1]) # do trabalho 1
df.head()
# Out:
#                      Graph              Exhaustive                 Heuristic  \
#                       name  n  m weight       #ops      time #sols      #ops
# 0  graphs/0004_125.graphml  4  0    0.0       68.0  0.000024  16.0        28
# 1  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0        28
# 2  graphs/0004_500.graphml  4  3   38.0       74.0  0.000026  16.0        29
# 3  graphs/0004_750.graphml  4  4   36.0       72.0  0.000023  16.0        29
# 4  graphs/0005_125.graphml  5  1   18.0      199.0  0.000058  32.0        53
#
#
#        time #sols prec.
# 0  0.000007     1   1.0
# 1  0.000008     1   1.0
# 2  0.000009     1   1.0
# 3  0.000008     1   1.0
# 4  0.000009     1   1.0

# %%
pd.read_excel('results v03.xlsx', index_col=0, header=[0,1]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5517 entries, 0 to 5516
# Data columns (total 53 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   (Graph, name)                                     5517 non-null   object
#  1   (Graph, n)                                        5517 non-null   int64
#  2   (Graph, m)                                        5517 non-null   int64
#  3   (Graph, weight)                                   2394 non-null   float64
#  4   (Exhaustive, #ops)                                1535 non-null   float64
#  5   (Exhaustive, time)                                1535 non-null   float64
#  6   (Exhaustive, #sols)                               1535 non-null   float64
#  7   (Heuristic, #ops)                                 5517 non-null   int64
#  8   (Heuristic, time)                                 5517 non-null   float64
#  9   (Heuristic, #sols)                                5517 non-null   int64
#  10  (Heuristic, prec.)                                2394 non-null   float64
#  11  (Random Solutions (MS: 10000), #ops)              1481 non-null   float64
#  12  (Random Solutions (MS: 10000), time)              1481 non-null   float64
#  13  (Random Solutions (MS: 10000), #sols)             1481 non-null   float64
#  14  (Random Solutions (MS: 10000), prec.)             607 non-null    float64
#  15  (Random Solutions (MS: 10000), it.)               1481 non-null   float64
#  16  (Random Solutions (MS: 10000), prec./it.)         607 non-null    float64
#  17  (Simulated Annealing (T: 1000, CR: 0.99), #ops)   1481 non-null   float64
#  18  (Simulated Annealing (T: 1000, CR: 0.99), time)   1481 non-null   float64
#  19  (Simulated Annealing (T: 1000, CR: 0.99), #sols)  1481 non-null   float64
#  20  (Simulated Annealing (T: 1000, CR: 0.99), prec.)  607 non-null    float64
#  21  (Random Greedy (IT: 2), #ops)                     1569 non-null   float64
#  22  (Random Greedy (IT: 2), time)                     1569 non-null   float64
#  23  (Random Greedy (IT: 2), #sols)                    1569 non-null   float64
#  24  (Random Greedy (IT: 2), prec.)                    552 non-null    float64
#  25  (Simulated Annealing (T: 100, CR: 0.99), #ops)    1477 non-null   float64
#  26  (Simulated Annealing (T: 100, CR: 0.99), time)    1477 non-null   float64
#  27  (Simulated Annealing (T: 100, CR: 0.99), #sols)   1477 non-null   float64
#  28  (Simulated Annealing (T: 100, CR: 0.99), prec.)   622 non-null    float64
#  29  (Random Greedy (IT: 0.1), #ops)                   490 non-null    float64
#  30  (Random Greedy (IT: 0.1), time)                   490 non-null    float64
#  31  (Random Greedy (IT: 0.1), #sols)                  490 non-null    float64
#  32  (Random Greedy (IT: 0.1), prec.)                  166 non-null    float64
#  33  (Random Solutions (MS: 1000), #ops)               658 non-null    float64
#  34  (Random Solutions (MS: 1000), time)               658 non-null    float64
#  35  (Random Solutions (MS: 1000), #sols)              658 non-null    float64
#  36  (Random Solutions (MS: 1000), prec.)              304 non-null    float64
#  37  (Random Solutions (MS: 1000), it.)                658 non-null    float64
#  38  (Random Solutions (MS: 1000), prec./it.)          304 non-null    float64
#  39  (Simulated Annealing (T: 1000, CR: 0.95), #ops)   658 non-null    float64
#  40  (Simulated Annealing (T: 1000, CR: 0.95), time)   658 non-null    float64
#  41  (Simulated Annealing (T: 1000, CR: 0.95), #sols)  658 non-null    float64
#  42  (Simulated Annealing (T: 1000, CR: 0.95), prec.)  304 non-null    float64
#  43  (Random Solutions (MS: 100), #ops)                987 non-null    float64
#  44  (Random Solutions (MS: 100), time)                987 non-null    float64
#  45  (Random Solutions (MS: 100), #sols)               987 non-null    float64
#  46  (Random Solutions (MS: 100), prec.)               456 non-null    float64
#  47  (Random Solutions (MS: 100), it.)                 987 non-null    float64
#  48  (Random Solutions (MS: 100), prec./it.)           456 non-null    float64
#  49  (Simulated Annealing (T: 1000, CR: 0.9), #ops)    987 non-null    float64
#  50  (Simulated Annealing (T: 1000, CR: 0.9), time)    987 non-null    float64
#  51  (Simulated Annealing (T: 1000, CR: 0.9), #sols)   987 non-null    float64
#  52  (Simulated Annealing (T: 1000, CR: 0.9), prec.)   456 non-null    float64
# dtypes: float64(48), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
import numpy as np
dateFile = str(datetime.now().strftime("%m%d%H%M%S")) 

alg1_ops = [np.nan for _ in range(len(df))]
alg1_time = [np.nan for _ in range(len(df))]
alg1_sols = [np.nan for _ in range(len(df))]
alg1_prec = [np.nan for _ in range(len(df))]
alg1_it = [np.nan for _ in range(len(df))]
alg1_prec_it = [np.nan for _ in range(len(df))]

alg2_ops = [np.nan for _ in range(len(df))]
alg2_time = [np.nan for _ in range(len(df))]
alg2_sols = [np.nan for _ in range(len(df))]
alg2_prec = [np.nan for _ in range(len(df))]

alg3_ops = [np.nan for _ in range(len(df))]
alg3_time = [np.nan for _ in range(len(df))]
alg3_sols = [np.nan for _ in range(len(df))]
alg3_prec = [np.nan for _ in range(len(df))]

indices = np.arange(len(df))
np.random.shuffle(indices)

for i in range(len(df)): # range(len(df)) range(len(df)-1, -1, -1) indices
    graph = df[("Graph", "name")][i]
    n = df[("Graph", "n")][i]
    m = df[("Graph", "m")][i]
    weight = df[("Graph", "weight")][i]
    print(f"Solving {graph}: {datetime.now().strftime('%H%M')}")

    # prepare the graph
    if "gset" in graph:
        edges, n_nodes, n_edges = edges_from_Bgraph(graph)
    elif "graphs/" in graph:
        edges, n_nodes, n_edges = adjacency_matrix_to_edges(graph)



    
    max_solutions = 10000       #################################### <--- mudar se quiseres
    ALG1 = f"Random Solutions (MS: {max_solutions})"
    start_time = time.time()
    #S, T, best_cut_weight, SOLTESTED, OPSEXEC, ACTUAL_IT, MEAN_WEIGHT = random_solution(edges, n_nodes, solutions=max_solutions)
    timee = time.time() - start_time
    alg1_ops[i] = np.nan #OPSEXEC
    alg1_time[i] = np.nan #timee
    alg1_sols[i] = np.nan #SOLTESTED
    alg1_prec[i] = np.nan #best_cut_weight/weight
    alg1_it[i] = np.nan #ACTUAL_IT
    alg1_prec_it[i] = np.nan #MEAN_WEIGHT/weight

    
    temperature = 1000          #################################### <--- mudar se quiseres
    cooling_rate = 0.99         #################################### <--- mudar se quiseres
    ALG2 = f"Simulated Annealing (T: {temperature}, CR: {cooling_rate})"
    start_time = time.time()
    S, T, best_cut, SOLTESTED, OPSEXEC = sim_anlng(edges, n_nodes, initial_temp=temperature, cooling_rate=cooling_rate)
    timee = time.time() - start_time
    alg2_ops[i] = OPSEXEC
    alg2_time[i] = timee
    alg2_sols[i] = SOLTESTED
    alg2_prec[i] = best_cut/weight

    it_limite = 2               #################################### <--- mudar se quiseres
    ALG3 = f"Random Greedy (IT: {it_limite})"
    start_time = time.time()
    #S, T, cut_weight, SOLTESTED, OPSEXEC = random_greedy(edges, n_nodes, itLim = it_limite)
    timee = time.time() - start_time
    alg3_ops[i] = np.nan #OPSEXEC
    alg3_time[i] = np.nan #timee
    alg3_sols[i] = np.nan #SOLTESTED
    alg3_prec[i] = np.nan #cut_weight/weight


    df[(ALG1, "#ops")] = alg1_ops
    df[(ALG1, "time")] = alg1_time
    df[(ALG1, "#sols")] = alg1_sols
    df[(ALG1, "prec.")] = alg1_prec
    df[(ALG1, "it.")] = alg1_it
    df[(ALG1, "prec./it.")] = alg1_prec_it

    df[(ALG2, "#ops")] = alg2_ops
    df[(ALG2, "time")] = alg2_time
    df[(ALG2, "#sols")] = alg2_sols
    df[(ALG2, "prec.")] = alg2_prec

    df[(ALG3, "#ops")] = alg3_ops
    df[(ALG3, "time")] = alg3_time
    df[(ALG3, "#sols")] = alg3_sols
    df[(ALG3, "prec.")] = alg3_prec


    df.to_excel(f"results_{dateFile}.xlsx")

print("Done! i hope...")
# Out:
# Solving graphs/0004_125.graphml: 1827
# Solving graphs/0004_250.graphml: 1827
# /var/folders/sz/96b_h5gn3y33k0c7jsvrstmm0000gn/T/ipykernel_6313/1030124385.py:62: RuntimeWarning: invalid value encountered in scalar divide
#   alg2_prec[i] = best_cut/weight
# Solving graphs/0004_500.graphml: 1827
# Solving graphs/0004_750.graphml: 1827
# Solving graphs/0005_125.graphml: 1827
# Solving graphs/0005_250.graphml: 1827
# Solving graphs/0005_500.graphml: 1827
# Solving graphs/0005_750.graphml: 1827
# Solving graphs/0006_125.graphml: 1827
# Solving graphs/0006_250.graphml: 1827
# Solving graphs/0006_500.graphml: 1827
# Solving graphs/0006_750.graphml: 1827
# Solving graphs/0007_125.graphml: 1827
# Solving graphs/0007_250.graphml: 1827
# Solving graphs/0007_500.graphml: 1827
# Solving graphs/0007_750.graphml: 1827
# Solving graphs/0008_125.graphml: 1827
# Solving graphs/0008_250.graphml: 1827
# Solving graphs/0008_500.graphml: 1827
# Solving graphs/0008_750.graphml: 1827
# Solving graphs/0009_125.graphml: 1827
# Solving graphs/0009_250.graphml: 1827
# Solving graphs/0009_500.graphml: 1827
# Solving graphs/0009_750.graphml: 1827
# Solving graphs/0010_125.graphml: 1827
# Solving graphs/0010_250.graphml: 1827
# Solving graphs/0010_500.graphml: 1827
# Solving graphs/0010_750.graphml: 1827
# Solving graphs/0011_125.graphml: 1827
# Solving graphs/0011_250.graphml: 1827
# Solving graphs/0011_500.graphml: 1827
# Solving graphs/0011_750.graphml: 1827
# Solving graphs/0012_125.graphml: 1827
# Solving graphs/0012_250.graphml: 1827
# Solving graphs/0012_500.graphml: 1827
# Solving graphs/0012_750.graphml: 1827
# Solving graphs/0013_125.graphml: 1827
# Solving graphs/0013_250.graphml: 1827
# Solving graphs/0049_500.graphml: 1827
# Solving graphs/0049_750.graphml: 1827
# Solving graphs/0050_125.graphml: 1827
# Solving graphs/0050_250.graphml: 1827
# Solving graphs/0050_500.graphml: 1827
# Solving graphs/0050_750.graphml: 1827
# Solving graphs/0055_125.graphml: 1827
# Solving graphs/0055_250.graphml: 1827
# Solving graphs/0055_500.graphml: 1827
# Solving graphs/0055_750.graphml: 1827
# Solving graphs/0060_125.graphml: 1827
# Solving graphs/0060_250.graphml: 1827
# Solving graphs/0060_500.graphml: 1827
# Solving graphs/0060_750.graphml: 1827
# Solving graphs/0065_125.graphml: 1827
# Solving graphs/0065_250.graphml: 1827
# Solving graphs/0065_500.graphml: 1827
# Solving graphs/0065_750.graphml: 1827
# Solving graphs/0070_125.graphml: 1827
# Solving graphs/0070_250.graphml: 1827
# Solving graphs/0070_500.graphml: 1827
# Solving graphs/0070_750.graphml: 1827
# Solving graphs/0075_125.graphml: 1827
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 93
#      89     df[(ALG3, "#sols")] = alg3_sols
#      90     df[(ALG3, "prec.")] = alg3_prec
# ---> 93     df.to_excel(f"results_{dateFile}.xlsx")
#      95 print("Done! i hope...")
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/pandas/core/generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/pandas/io/formats/excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/pandas/io/excel/_openpyxl.py:83, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      80 else:
#      81     # Create workbook object with default optimized_write=True.
#      82     try:
# ---> 83         self._book = Workbook(**engine_kwargs)
#      84     except TypeError:
#      85         self._handles.handle.close()
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/openpyxl/workbook/workbook.py:85, in Workbook.__init__(self, write_only, iso_dates)
#      82 self.iso_dates = iso_dates
#      84 if not self.write_only:
# ---> 85     self._sheets.append(Worksheet(self))
#      87 self.rels = RelationshipList()
#      88 self.calculation = CalcProperties()
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/openpyxl/worksheet/worksheet.py:107, in Worksheet.__init__(self, parent, title)
#     105 def __init__(self, parent, title=None):
#     106     _WorkbookChild.__init__(self, parent, title)
# --> 107     self._setup()
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/openpyxl/worksheet/worksheet.py:128, in Worksheet._setup(self)
#     126 self._hyperlinks = []
#     127 self.sheet_state = 'visible'
# --> 128 self.page_setup = PrintPageSetup(worksheet=self)
#     129 self.print_options = PrintOptions()
#     130 self._print_rows = None
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/openpyxl/worksheet/page.py:70, in PrintPageSetup.__init__(self, worksheet, orientation, paperSize, scale, fitToHeight, fitToWidth, firstPageNumber, useFirstPageNumber, paperHeight, paperWidth, pageOrder, usePrinterDefaults, blackAndWhite, draft, cellComments, errors, horizontalDpi, verticalDpi, copies, id)
#      68 self.paperHeight = paperHeight
#      69 self.paperWidth = paperWidth
# ---> 70 self.pageOrder = pageOrder
#      71 self.usePrinterDefaults = usePrinterDefaults
#      72 self.blackAndWhite = blackAndWhite
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/openpyxl/descriptors/base.py:147, in NoneSet.__set__(self, instance, value)
#     145 if value == 'none':
#     146     value = None
# --> 147 super().__set__(instance, value)
#
# File /opt/anaconda3/envs/AA/lib/python3.10/site-packages/openpyxl/descriptors/base.py:131, in Set.__set__(self, instance, value)
#     130 def __set__(self, instance, value):
# --> 131     if value not in self.values:
#     132         raise ValueError(self.__doc__)
#     133     super().__set__(instance, value)
#
# KeyboardInterrupt:

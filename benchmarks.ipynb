# %%
import networkx as nx
import random
import math

# %% [markdown]
# # funcoes para ler grafos

# %%
def adjacency_matrix_to_edges(G_graphml):
    matrix = nx.adjacency_matrix(nx.read_graphml(G_graphml)).todense()
    edges = []
    n = len(matrix)  # assuming matrix is square
    for u in range(n):
        for v in range(u, n):
            if matrix[u][v] != 0:  # assuming 0 means no edge
                edges.append((u, v, matrix[u][v]))
    return edges, n, len(edges)

G = 'graphs/0004_125.graphml'
edges, n_nodes, m = adjacency_matrix_to_edges(G)

# %%
def edges_from_Bgraph(filename):
    edges = []
    with open(filename, 'r') as file:
        # Skip the first line
        if "gset" in filename:
            n_nodes, n_edges = file.readline().split()
            n_nodes, n_edges = int(n_nodes), int(n_edges)
        else:
            file.readline()
            file.readline()
            n_nodes = int(file.readline().split()[0])
            n_edges = int(file.readline().split()[0])
        for line in file:
            # Split each line into components and convert to appropriate types
            node1, node2, weight = line.split()
            edges.append((int(node1)-1, int(node2)-1, float(weight)))
    return edges, n_nodes, n_edges

#path = """graphs (gset)/G59.txt"""
#edges_from_Bgraph(path)

# %% [markdown]
# # algorimos

# %%
def random_solution(edges, n_nodes, solutions=10000):
    SOLTESTED, OPSEXEC = 0, 0

    best_solution = {node: 0 for node in range(n_nodes)}
    best_cut_weight = 0
    seen_solutions = set()

    MEAN_WEIGHT = 0
    for _ in range(solutions):
        # Generate a random candidate solution
        partition = {node: random.choice([0, 1]) for node in range(n_nodes)}
        OPSEXEC += n_nodes
        # avoid calculating the same solution multiple times
        partition_hash = frozenset(partition.items()) # hash
        # nao vou contabilizar o custo de calcular o hash pq não seria necessário se só testasse uma solucao
        # e em grafos de maior dimensao, a probabilidade de ter solucoes iguais tende para 0 (2^n possiblidades)

        if len(seen_solutions) == 2**(n_nodes): # max possible solutions
            break
        
        if partition_hash in seen_solutions:
            continue

        
        

        seen_solutions.add(partition_hash)
        OPSEXEC += 1
        SOLTESTED += 1
        new_cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
        MEAN_WEIGHT += new_cut_weight
        OPSEXEC += len(edges)
        if new_cut_weight > best_cut_weight:
            best_cut_weight = new_cut_weight
            best_solution = partition.copy()
            OPSEXEC += 2

    actual_it = _ + 1
    S = set([node for node, part in best_solution.items() if part == 0]) #pos processamento, depende do q ser quer, n conta
    T = set(range(n_nodes)) - S #pos processamento, depende do q ser quer, n conta
    return S, T, best_cut_weight, SOLTESTED, OPSEXEC, actual_it, MEAN_WEIGHT/actual_it

S, T, best_cut_weight, SOLTESTED, OPSEXEC, actual_it, MEAN_WEIGHT = random_solution(edges, n_nodes)
S, T, best_cut_weight, SOLTESTED, OPSEXEC, actual_it, MEAN_WEIGHT
# Out:
# ({0, 1, 2, 3}, set(), 0, 16, 240, 56, 0.0)

# %%
def sim_anlng(edges, n_nodes, initial_temp=1000, cooling_rate=0.995, min_temp=1e-3):
    SOLTESTED, OPSEXEC = 0, 0

    nodes = range(n_nodes)
    
    partition = {node: random.choice([0, 1]) for node in nodes}
    OPSEXEC += n_nodes
    
    # Initialize current cost
    current_cut = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
    OPSEXEC += len(edges)
    SOLTESTED += 1

    temperature = initial_temp

    best_partition = partition.copy()
    best_cut = current_cut
    while temperature > min_temp:

        node = random.choice(nodes)
        partition[node] = 1 - partition[node] 
        OPSEXEC += 2
        
        new_cut = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
        OPSEXEC += len(edges)
        SOLTESTED += 1
        
        cost_diff = new_cut - current_cut
        if cost_diff > 0 or random.random() < math.exp(cost_diff / temperature):
            current_cut = new_cut
            if new_cut > best_cut:
                best_cut = new_cut
                best_partition = partition.copy()
                OPSEXEC += 5
        else:
            partition[node] = 1 - partition[node]
            OPSEXEC += 3
        
        temperature *= cooling_rate
        OPSEXEC += 1
    
    S = set([node for node, part in best_partition.items() if part == 0])
    T = set(range(n_nodes)) - S
    return S, T, best_cut, SOLTESTED, OPSEXEC

S, T, best_cut, SOLTESTED, OPSEXEC = sim_anlng(edges, n_nodes)
S, T, best_cut, SOLTESTED, OPSEXEC
# Out:
# ({0, 3}, {1, 2}, 0, 2758, 8275)

# %%
def random_greedy(edges, n_nodes, itLim = 2):
    SOLTESTED, OPSEXEC = 0, 0

    partition = {node: random.choice([0, 1]) for node in range(n_nodes)}
    cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
    SOLTESTED += 1
    OPSEXEC += len(edges) + n_nodes

    improved = True
    it_limit = len(edges) * itLim
    OPSEXEC += 1
    while improved and it_limit > 0:
        it_limit -= 1
        OPSEXEC += 1
        improved = False
        for node in range(n_nodes):
            # Flip the node to the other set
            partition[node] = 1 - partition[node]  
            new_cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
            SOLTESTED += 1
            OPSEXEC += len(edges) + 1

            # If this move improves the cut weight, keep it; otherwise, revert
            if new_cut_weight > cut_weight:
                cut_weight = new_cut_weight
                improved = True  # Continue improving
                OPSEXEC += 2
                break
            else:
                partition[node] = 1 - partition[node]
                OPSEXEC += 1

    S = set([node for node, part in partition.items() if part == 0])
    T = set(range(n_nodes)) - S
    return S, T, cut_weight, SOLTESTED, OPSEXEC

S, T, cut_weight, SOLTESTED, OPSEXEC = random_greedy(edges, n_nodes)
S, T, cut_weight, SOLTESTED, OPSEXEC
# Out:
# ({0, 1}, {2, 3}, 0, 1, 5)

# %% [markdown]
# # benchmarks

# %%
import pandas as pd
from datetime import datetime
import time

df = pd.read_excel('results v00.xlsx', index_col=0, header=[0,1]) # do trabalho 1
df.head()
# Out:
#                      Graph              Exhaustive                 Heuristic  \
#                       name  n  m weight       #ops      time #sols      #ops
# 0  graphs/0004_125.graphml  4  0    0.0       68.0  0.000024  16.0        28
# 1  graphs/0004_250.graphml  4  1   13.0       70.0  0.000023  16.0        28
# 2  graphs/0004_500.graphml  4  3   38.0       74.0  0.000026  16.0        29
# 3  graphs/0004_750.graphml  4  4   36.0       72.0  0.000023  16.0        29
# 4  graphs/0005_125.graphml  5  1   18.0      199.0  0.000058  32.0        53
#
#
#        time #sols prec.
# 0  0.000007     1   1.0
# 1  0.000008     1   1.0
# 2  0.000009     1   1.0
# 3  0.000008     1   1.0
# 4  0.000009     1   1.0

# %%
import numpy as np
dateFile = str(datetime.now().strftime("%m%d%H%M%S")) 

alg1_ops = [np.nan for _ in range(len(df))]
alg1_time = [np.nan for _ in range(len(df))]
alg1_sols = [np.nan for _ in range(len(df))]
alg1_prec = [np.nan for _ in range(len(df))]
alg1_it = [np.nan for _ in range(len(df))]
alg1_prec_it = [np.nan for _ in range(len(df))]

alg2_ops = [np.nan for _ in range(len(df))]
alg2_time = [np.nan for _ in range(len(df))]
alg2_sols = [np.nan for _ in range(len(df))]
alg2_prec = [np.nan for _ in range(len(df))]

alg3_ops = [np.nan for _ in range(len(df))]
alg3_time = [np.nan for _ in range(len(df))]
alg3_sols = [np.nan for _ in range(len(df))]
alg3_prec = [np.nan for _ in range(len(df))]

indices = np.arange(len(df))
np.random.shuffle(indices)

for i in range(len(df)): # range(len(df)) range(len(df)-1, -1, -1) indices
    graph = df[("Graph", "name")][i]
    n = df[("Graph", "n")][i]
    m = df[("Graph", "m")][i]
    weight = df[("Graph", "weight")][i]
    print(f"Solving {graph}: {datetime.now().strftime('%H%M')}")

    # prepare the graph
    if "gset" in graph:
        edges, n_nodes, n_edges = edges_from_Bgraph(graph)
    elif "graphs/" in graph:
        edges, n_nodes, n_edges = adjacency_matrix_to_edges(graph)



    
    max_solutions = 10000       #################################### <--- mudar se quiseres
    ALG1 = f"Random Solutions (MS: {max_solutions})"
    start_time = time.time()
    #S, T, best_cut_weight, SOLTESTED, OPSEXEC, ACTUAL_IT, MEAN_WEIGHT = random_solution(edges, n_nodes, solutions=max_solutions)
    timee = time.time() - start_time
    alg1_ops[i] = np.nan #OPSEXEC #OPSEXEC
    alg1_time[i] = np.nan #timee #timee
    alg1_sols[i] = np.nan #SOLTESTED #SOLTESTED
    alg1_prec[i] = np.nan #best_cut_weight/weight #best_cut_weight/weight
    alg1_it[i] = np.nan #ACTUAL_IT #ACTUAL_IT
    alg1_prec_it[i] = np.nan #MEAN_WEIGHT/weight #MEAN_WEIGHT/weight

    
    temperature = 1000          #################################### <--- mudar se quiseres
    cooling_rate = 0.99         #################################### <--- mudar se quiseres
    ALG2 = f"Simulated Annealing (T: {temperature}, CR: {cooling_rate})"
    start_time = time.time()
    #S, T, best_cut, SOLTESTED, OPSEXEC = sim_anlng(edges, n_nodes, initial_temp=temperature, cooling_rate=cooling_rate)
    timee = time.time() - start_time
    alg2_ops[i] = np.nan #OPSEXEC
    alg2_time[i] = np.nan #timee
    alg2_sols[i] = np.nan #SOLTESTED
    alg2_prec[i] = np.nan #best_cut/weight

    it_limite = 0.01 #2               #################################### <--- mudar se quiseres
    ALG3 = f"Random Greedy (IT: {it_limite})"
    start_time = time.time()
    S, T, cut_weight, SOLTESTED, OPSEXEC = random_greedy(edges, n_nodes, itLim = it_limite)
    timee = time.time() - start_time
    alg3_ops[i] = OPSEXEC #np.nan #OPSEXEC
    alg3_time[i] = timee #timee
    alg3_sols[i] = SOLTESTED #SOLTESTED
    alg3_prec[i] = cut_weight/weight #cut_weight/weight

    # APAGAR APAGAR  APAGAR  APAGAR  APAGAR APAGAR  APAGAR  APAGAR  APAGAR  APAGAR  APAGAR 
    it_limite = 0.1 #2              # APAGAR
    ALG2 = f"Random Greedy (IT: {it_limite})"
    start_time = time.time()
    S, T, cut_weight, SOLTESTED, OPSEXEC = random_greedy(edges, n_nodes, itLim = it_limite)
    timee = time.time() - start_time
    alg2_ops[i] = OPSEXEC #np.nan #OPSEXEC
    alg2_time[i] = timee #timee
    alg2_sols[i] = SOLTESTED #SOLTESTED
    alg2_prec[i] = cut_weight/weight #cut_weight/weight
    # APAGAR APAGAR  APAGAR  APAGAR  APAGAR APAGAR  APAGAR  APAGAR  APAGAR  APAGAR  APAGAR 


    df[(ALG1, "#ops")] = alg1_ops
    df[(ALG1, "time")] = alg1_time
    df[(ALG1, "#sols")] = alg1_sols
    df[(ALG1, "prec.")] = alg1_prec
    df[(ALG1, "it.")] = alg1_it
    df[(ALG1, "prec./it.")] = alg1_prec_it

    df[(ALG2, "#ops")] = alg2_ops
    df[(ALG2, "time")] = alg2_time
    df[(ALG2, "#sols")] = alg2_sols
    df[(ALG2, "prec.")] = alg2_prec

    df[(ALG3, "#ops")] = alg3_ops
    df[(ALG3, "time")] = alg3_time
    df[(ALG3, "#sols")] = alg3_sols
    df[(ALG3, "prec.")] = alg3_prec


    df.to_excel(f"results_{dateFile}.xlsx")

print("Done! i hope...")
# Out:
# Solving graphs/0004_125.graphml: 1306
# Solving graphs/0004_250.graphml: 1306
# Solving graphs/0004_500.graphml: 1306
# /var/folders/sz/96b_h5gn3y33k0c7jsvrstmm0000gn/T/ipykernel_1905/3204137253.py:72: RuntimeWarning: invalid value encountered in scalar divide
#   alg3_prec[i] = cut_weight/weight #cut_weight/weight
# /var/folders/sz/96b_h5gn3y33k0c7jsvrstmm0000gn/T/ipykernel_1905/3204137253.py:83: RuntimeWarning: invalid value encountered in scalar divide
#   alg2_prec[i] = cut_weight/weight #cut_weight/weight
# Solving graphs/0004_750.graphml: 1306
# Solving graphs/0005_125.graphml: 1306
# Solving graphs/0005_250.graphml: 1306
# Solving graphs/0005_500.graphml: 1306
# Solving graphs/0005_750.graphml: 1306
# Solving graphs/0006_125.graphml: 1306
# Solving graphs/0006_250.graphml: 1306
# Solving graphs/0006_500.graphml: 1306
# Solving graphs/0006_750.graphml: 1306
# Solving graphs/0007_125.graphml: 1306
# Solving graphs/0007_250.graphml: 1306
# Solving graphs/0007_500.graphml: 1306
# Solving graphs/0007_750.graphml: 1306
# Solving graphs/0008_125.graphml: 1306
# Solving graphs/0008_250.graphml: 1306
# Solving graphs/0008_500.graphml: 1306
# Solving graphs/0008_750.graphml: 1306
# Solving graphs/0009_125.graphml: 1306
# Solving graphs/0009_250.graphml: 1306
# Solving graphs/0009_500.graphml: 1306
# Solving graphs/0009_750.graphml: 1306
# Solving graphs/0010_125.graphml: 1306
# Solving graphs/0010_250.graphml: 1306
# Solving graphs/0010_500.graphml: 1306
# Solving graphs/0010_750.graphml: 1306
# Solving graphs/0011_125.graphml: 1306
# Solving graphs/0011_250.graphml: 1306
# Solving graphs/0011_500.graphml: 1306
# Solving graphs/0011_750.graphml: 1306
# Solving graphs/0012_125.graphml: 1306
# Solving graphs/0012_250.graphml: 1306
# Solving graphs/0012_500.graphml: 1306
# Solving graphs/0012_750.graphml: 1306
# Solving graphs/0013_125.graphml: 1306
# Solving graphs/0013_250.graphml: 1306
# Solving graphs/0013_500.graphml: 1306
# Solving graphs/0013_750.graphml: 1307
# Solving graphs/0014_125.graphml: 1307
# Solving graphs/0014_250.graphml: 1307
# Solving graphs/0014_500.graphml: 1307
# Solving graphs/0014_750.graphml: 1307
# Solving graphs/0015_125.graphml: 1307
# Solving graphs/0015_250.graphml: 1307
# Solving graphs/0015_500.graphml: 1307
# Solving graphs/0015_750.graphml: 1307
# Solving graphs/0016_125.graphml: 1307
# Solving graphs/0016_250.graphml: 1307
# Solving graphs/0016_500.graphml: 1307
# Solving graphs/0016_750.graphml: 1307
# Solving graphs/0017_125.graphml: 1307
# Solving graphs/0017_250.graphml: 1307
# Solving graphs/0017_500.graphml: 1307
# Solving graphs/0017_750.graphml: 1307
# Solving graphs/0018_125.graphml: 1307
# Solving graphs/0018_250.graphml: 1307
# Solving graphs/0018_500.graphml: 1307
# Solving graphs/0018_750.graphml: 1307
# Solving graphs/0019_125.graphml: 1307
# Solving graphs/0019_250.graphml: 1307
# Solving graphs/0019_500.graphml: 1307
# Solving graphs/0019_750.graphml: 1307
# Solving graphs/0020_125.graphml: 1307
# Solving graphs/0020_250.graphml: 1307
# Solving graphs/0020_500.graphml: 1307
# Solving graphs/0020_750.graphml: 1307
# Solving graphs/0021_125.graphml: 1307
# Solving graphs/0021_250.graphml: 1307
# Solving graphs/0021_500.graphml: 1307
# Solving graphs/0021_750.graphml: 1307
# Solving graphs/0022_125.graphml: 1307
# Solving graphs/0022_250.graphml: 1307
# Solving graphs/0022_500.graphml: 1307
# Solving graphs/0022_750.graphml: 1307
# Solving graphs/0023_125.graphml: 1307
# Solving graphs/0023_250.graphml: 1307
# Solving graphs/0023_500.graphml: 1307
# Solving graphs/0023_750.graphml: 1307
# Solving graphs/0024_125.graphml: 1307
# Solving graphs/0024_250.graphml: 1307
# Solving graphs/0024_500.graphml: 1307
# Solving graphs/0024_750.graphml: 1307
# Solving graphs/0025_125.graphml: 1307
# Solving graphs/0025_250.graphml: 1307
# Solving graphs/0025_500.graphml: 1307
# Solving graphs/0025_750.graphml: 1307
# Solving graphs/0026_125.graphml: 1307
# Solving graphs/0026_250.graphml: 1307
# Solving graphs/0026_500.graphml: 1307
# Solving graphs/0026_750.graphml: 1307
# Solving graphs/0027_125.graphml: 1307
# Solving graphs/0027_250.graphml: 1307
# Solving graphs/0027_500.graphml: 1307
# Solving graphs/0027_750.graphml: 1307
# Solving graphs/0028_125.graphml: 1307
# Solving graphs/0028_250.graphml: 1307
# Solving graphs/0028_500.graphml: 1307
# Solving graphs/0028_750.graphml: 1307
# Solving graphs/0029_125.graphml: 1307
# Solving graphs/0029_250.graphml: 1307
# Solving graphs/0029_500.graphml: 1307
# Solving graphs/0029_750.graphml: 1307
# Solving graphs/0030_125.graphml: 1307
# Solving graphs/0030_250.graphml: 1307
# Solving graphs/0030_500.graphml: 1307
# Solving graphs/0030_750.graphml: 1307
# Solving graphs/0031_125.graphml: 1307
# Solving graphs/0031_250.graphml: 1307
# Solving graphs/0031_500.graphml: 1307
# Solving graphs/0031_750.graphml: 1307
# Solving graphs/0032_125.graphml: 1307
# Solving graphs/0032_250.graphml: 1307
# Solving graphs/0032_500.graphml: 1307
# Solving graphs/0032_750.graphml: 1307
# Solving graphs/0033_125.graphml: 1307
# Solving graphs/0033_250.graphml: 1307
# Solving graphs/0033_500.graphml: 1307
# Solving graphs/0033_750.graphml: 1307
# Solving graphs/0034_125.graphml: 1307
# Solving graphs/0034_250.graphml: 1307
# Solving graphs/0034_500.graphml: 1307
# Solving graphs/0034_750.graphml: 1307
# Solving graphs/0035_125.graphml: 1307
# Solving graphs/0035_250.graphml: 1307
# Solving graphs/0035_500.graphml: 1307
# Solving graphs/0035_750.graphml: 1307
# Solving graphs/0036_125.graphml: 1307
# Solving graphs/0036_250.graphml: 1307
# Solving graphs/0036_500.graphml: 1307
# Solving graphs/0036_750.graphml: 1307
# Solving graphs/0037_125.graphml: 1307
# Solving graphs/0037_250.graphml: 1307
# Solving graphs/0037_500.graphml: 1307
# Solving graphs/0037_750.graphml: 1307
# Solving graphs/0038_125.graphml: 1307
# Solving graphs/0038_250.graphml: 1307
# Solving graphs/0038_500.graphml: 1307
# Solving graphs/0038_750.graphml: 1307
# Solving graphs/0039_125.graphml: 1307
# Solving graphs/0039_250.graphml: 1307
# Solving graphs/0039_500.graphml: 1307
# Solving graphs/0039_750.graphml: 1307
# Solving graphs/0040_125.graphml: 1307
# Solving graphs/0040_250.graphml: 1307
# Solving graphs/0040_500.graphml: 1307
# Solving graphs/0040_750.graphml: 1307
# Solving graphs/0041_125.graphml: 1307
# Solving graphs/0041_250.graphml: 1307
# Solving graphs/0041_500.graphml: 1307
# Solving graphs/0041_750.graphml: 1307
# Solving graphs/0042_125.graphml: 1307
# Solving graphs/0042_250.graphml: 1307
# Solving graphs/0042_500.graphml: 1307
# Solving graphs/0042_750.graphml: 1307
# Solving graphs/0043_125.graphml: 1307
# Solving graphs/0043_250.graphml: 1307
# Solving graphs/0043_500.graphml: 1307
# Solving graphs/0043_750.graphml: 1307
# Solving graphs/0044_125.graphml: 1307
# Solving graphs/0044_250.graphml: 1307
# Solving graphs/0044_500.graphml: 1307
# Solving graphs/0044_750.graphml: 1307
# Solving graphs/0045_125.graphml: 1307
# Solving graphs/0045_250.graphml: 1307
# Solving graphs/0045_500.graphml: 1307
# Solving graphs/0045_750.graphml: 1307
# Solving graphs/0046_125.graphml: 1307
# Solving graphs/0046_250.graphml: 1307
# Solving graphs/0046_500.graphml: 1307
# Solving graphs/0046_750.graphml: 1307
# Solving graphs/0047_125.graphml: 1307
# Solving graphs/0047_250.graphml: 1307
# Solving graphs/0047_500.graphml: 1307
# Solving graphs/0047_750.graphml: 1307
# Solving graphs/0048_125.graphml: 1307
# Solving graphs/0048_250.graphml: 1307
# Solving graphs/0048_500.graphml: 1307
# Solving graphs/0048_750.graphml: 1307
# Solving graphs/0049_125.graphml: 1307
# Solving graphs/0049_250.graphml: 1307
# Solving graphs/0049_500.graphml: 1307
# Solving graphs/0049_750.graphml: 1307
# Solving graphs/0050_125.graphml: 1307
# Solving graphs/0050_250.graphml: 1307
# Solving graphs/0050_500.graphml: 1307
# Solving graphs/0050_750.graphml: 1307
# Solving graphs/0055_125.graphml: 1307
# Solving graphs/0055_250.graphml: 1307
# Solving graphs/0055_500.graphml: 1307
# Solving graphs/0055_750.graphml: 1307
# Solving graphs/0060_125.graphml: 1307
# Solving graphs/0060_250.graphml: 1307
# Solving graphs/0060_500.graphml: 1307
# Solving graphs/0060_750.graphml: 1307
# Solving graphs/0065_125.graphml: 1307
# Solving graphs/0065_250.graphml: 1307
# Solving graphs/0065_500.graphml: 1307
# Solving graphs/0065_750.graphml: 1307
# Solving graphs/0070_125.graphml: 1307
# Solving graphs/0070_250.graphml: 1307
# Solving graphs/0070_500.graphml: 1307
# Solving graphs/0070_750.graphml: 1307
# Solving graphs/0075_125.graphml: 1307
# Solving graphs/0075_250.graphml: 1307
# Solving graphs/0075_500.graphml: 1307
# Solving graphs/0075_750.graphml: 1307
# Solving graphs/0080_125.graphml: 1307
# Solving graphs/0080_250.graphml: 1307
# Solving graphs/0080_500.graphml: 1307
# Solving graphs/0080_750.graphml: 1307
# Solving graphs/0085_125.graphml: 1307
# Solving graphs/0085_250.graphml: 1307
# Solving graphs/0085_500.graphml: 1307
# Solving graphs/0085_750.graphml: 1307
# Solving graphs/0090_125.graphml: 1307
# Solving graphs/0090_250.graphml: 1307
# Solving graphs/0090_500.graphml: 1307
# Solving graphs/0090_750.graphml: 1307
# Solving graphs/0095_125.graphml: 1307
# Solving graphs/0095_250.graphml: 1307
# Solving graphs/0095_500.graphml: 1307
# Solving graphs/0095_750.graphml: 1307
# Solving graphs/0100_125.graphml: 1307
# Solving graphs/0100_250.graphml: 1307
# Solving graphs/0100_500.graphml: 1307
# Solving graphs/0100_750.graphml: 1307
# Solving graphs/0150_125.graphml: 1307
# Solving graphs/0150_250.graphml: 1307
# Solving graphs/0150_500.graphml: 1307
# Solving graphs/0150_750.graphml: 1307
# Solving graphs/0200_125.graphml: 1307
# Solving graphs/0200_250.graphml: 1307
# Solving graphs/0200_500.graphml: 1307
# Solving graphs/0200_750.graphml: 1307
# Solving graphs/0250_125.graphml: 1308
# Solving graphs/0250_250.graphml: 1308
# Solving graphs/0250_500.graphml: 1308
# Solving graphs/0250_750.graphml: 1308
# Solving graphs/0300_125.graphml: 1309
# Solving graphs/0300_250.graphml: 1309
# Solving graphs/0300_500.graphml: 1310
# Solving graphs/0300_750.graphml: 1311
# Solving graphs/0350_125.graphml: 1313
# Solving graphs/0350_250.graphml: 1314
# Solving graphs/0350_500.graphml: 1315
# Solving graphs/0350_750.graphml: 1317
# Solving graphs/0400_125.graphml: 1322
# Solving graphs/0400_250.graphml: 1323
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 78
#      76 ALG2 = f"Random Greedy (IT: {it_limite})"
#      77 start_time = time.time()
# ---> 78 S, T, cut_weight, SOLTESTED, OPSEXEC = random_greedy(edges, n_nodes, itLim = it_limite)
#      79 timee = time.time() - start_time
#      80 alg2_ops[i] = OPSEXEC #np.nan #OPSEXEC
#
# Cell In[6], line 19, in random_greedy(edges, n_nodes, itLim)
#      16 for node in range(n_nodes):
#      17     # Flip the node to the other set
#      18     partition[node] = 1 - partition[node]
# ---> 19     new_cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
#      20     SOLTESTED += 1
#      21     OPSEXEC += len(edges) + 1
#
# Cell In[6], line 19, in <genexpr>(.0)
#      16 for node in range(n_nodes):
#      17     # Flip the node to the other set
#      18     partition[node] = 1 - partition[node]
# ---> 19     new_cut_weight = sum(weight for node1, node2, weight in edges if partition[node1] != partition[node2])
#      20     SOLTESTED += 1
#      21     OPSEXEC += len(edges) + 1
#
# KeyboardInterrupt:
